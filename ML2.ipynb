# %%
import pandas as pd
import numpy as np
df_main = pd.read_csv('/home/aidleroinc/Downloads/MLData.csv')

# %%
df = df_main.copy()

# %%
df
# Out:
#     Index  Umri  Jinsia       Mahali unapoishi  Nauli unayotumia kufika chuo  \
# 0       1  21.0    Male           Kijitonyama                            1.0
# 1       2  23.0    Male                  Sinza                         800.0
# 2       3  23.0    Male              Lugungira                         800.0
# 3       4   NaN     NaN                    NaN                           NaN
# 4       5  20.0    Male                   udsm                           NaN
# 5       6  20.0    Male                 Tegeta                         500.0
# 6       7  21.0    Male            Makumbusho                            NaN
# 7       8  21.0    Male                    Dar                         400.0
# 8       9  24.0    Male                Manyara                         400.0
# 9      10  20.0    Male                 Tegeta                         400.0
# 10     11  21.0    Male          Mabibo hostel                         400.0
# ...

# %%
del df['Submitter']
del df['Submission Date']
del df['Submission ID']

# %%
df
# Out:
#     Index  Umri  Jinsia       Mahali unapoishi  Nauli unayotumia kufika chuo  \
# 0       1  21.0    Male           Kijitonyama                            1.0
# 1       2  23.0    Male                  Sinza                         800.0
# 2       3  23.0    Male              Lugungira                         800.0
# 3       4   NaN     NaN                    NaN                           NaN
# 4       5  20.0    Male                   udsm                           NaN
# 5       6  20.0    Male                 Tegeta                         500.0
# 6       7  21.0    Male            Makumbusho                            NaN
# 7       8  21.0    Male                    Dar                         400.0
# 8       9  24.0    Male                Manyara                         400.0
# 9      10  20.0    Male                 Tegeta                         400.0
# 10     11  21.0    Male          Mabibo hostel                         400.0
# ...

# %%
df.columns = ['index','age','gender','location','tfee','distance','stipend']

# %%
df
# Out:
#     index   age  gender               location      tfee  distance  \
# 0       1  21.0    Male           Kijitonyama        1.0       1.0
# 1       2  23.0    Male                  Sinza     800.0       2.0
# 2       3  23.0    Male              Lugungira     800.0       8.0
# 3       4   NaN     NaN                    NaN       NaN       3.6
# 4       5  20.0    Male                   udsm       NaN       NaN
# 5       6  20.0    Male                 Tegeta     500.0      12.0
# 6       7  21.0    Male            Makumbusho        NaN       2.5
# 7       8  21.0    Male                    Dar     400.0       NaN
# 8       9  24.0    Male                Manyara     400.0       2.0
# 9      10  20.0    Male                 Tegeta     400.0       7.0
# 10     11  21.0    Male          Mabibo hostel     400.0       1.5
# 11     12  21.0    Male                 Golani    1000.0       3.4
# 12     13  21.0  Female                  Sinza     400.0       3.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     50 non-null     int64
#  1   age       48 non-null     float64
#  2   gender    48 non-null     object
#  3   location  48 non-null     object
#  4   tfee      40 non-null     float64
#  5   distance  39 non-null     float64
#  6   stipend   45 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 2.9+ KB

# %%
new_df = df.dropna()

# %%
new_df
# Out:
#     index   age  gender          location      tfee  distance      stipend
# 0       1  21.0    Male      Kijitonyama        1.0       1.0     250000.0
# 1       2  23.0    Male             Sinza     800.0       2.0    1000000.0
# 2       3  23.0    Male         Lugungira     800.0       8.0   10020000.0
# 5       6  20.0    Male            Tegeta     500.0      12.0     300000.0
# 8       9  24.0    Male           Manyara     400.0       2.0    2000000.0
# 9      10  20.0    Male            Tegeta     400.0       7.0     500000.0
# 10     11  21.0    Male     Mabibo hostel     400.0       1.5    1000000.0
# 12     13  21.0  Female             Sinza     400.0       3.2          1.0
# 13     14  23.0  Female     Dar es salaam     400.0       5.0    1000000.0
# 14     15  22.0  Female    Dar -es-Salaam     400.0       8.0     500000.0
# 15     16  21.0    Male          Magomeni     400.0       3.0     500000.0
# ...
