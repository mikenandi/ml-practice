# %%
import pandas as pd
from pandas.io.json import json_normalize 
import json 
# df = pd.read_json('/home/aidleroinc/Downloads/elsa-cervical-cancer.json')

# %%
# df = df.transpose()
# df.reset_index(drop=True, inplace=True)

# %%
 with open('/home/aidleroinc/Downloads/elsa-cervical-cancer.json') as f:
        d = json.load(f)
        df = pd.DataFrame(d)

# %%
# d.values()
df = df.transpose()
df.reset_index(drop=True, inplace=True)
df
# Out:
#       0        1     2               3        4              5        6   \
# 0     40       no  True  adenocarcinoma       7+  1403038800000       no
# 1     36  unknown  True        squamous       7+  1393880400000  unknown
# 2     40       no  True        squamous        4  1390251600000       no
# 3     48       no  True        squamous       7+  1393880400000  unknown
# 4     55       no  True        squamous  unknown  1391461200000       no
# ...   ..      ...   ...             ...      ...            ...      ...
# 999   60       no  True        squamous       7+   990565200000       no
# 1000  44      yes  True        squamous        6   988578000000  unknown
# 1001  48       no  True        squamous        6   985035600000  unknown
# 1002  36       no  True        squamous        2  1015189200000  unknown
# 1003  44       no  True        squamous        4  1020632400000  unknown
#
#           7   8        9                                                  10  \
# ...

# %%
# df.info()

# %%
# import json 
# import pandas 

# with open('/home/aidleroinc/Downloads/elsa-cervical-cancer.json') as f:  
#       data = json.load(f)
#       dn = pd.DataFrame(data)

# %%
# dn

# %%
dn = df.pop('tests')

# %%
# dn

# %%
# import pandas.io.json as pd_json
# data = pd_json.loads('/home/aidleroinc/Downloads/elsa-cervical-cancer.json')

# %%
# from pandas.io.json import json_normalize 
# df = json_normalize(df)
